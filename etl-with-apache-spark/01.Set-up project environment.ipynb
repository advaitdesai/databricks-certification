# %% [markdown]
# 1. Access to the container

# %%
# %fs ls 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/landing'

# %% [markdown]
# 2. create external location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_stac_gizmobox
    URL 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL dea_course_ext_sc)

# %% [markdown]
# 3. Create catalog - gizmobox

# %%
# %sql

CREATE CATALOG IF NOT EXISTS  gizmobox
    MANAGED LOCATION 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/' ;

# %% [markdown]
# 4. Create schemas
# - Landing
# - Bronz
# - Silver
# - Gold

# %%
# %sql
SELECT current_catalog();

# %%
# %sql
USE CATALOG gizmobox;

CREATE SCHEMA IF NOT EXISTS landing
    MANAGED LOCATION 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/landing';
CREATE SCHEMA IF NOT EXISTS bronze
    MANAGED LOCATION 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/bronze';
CREATE SCHEMA IF NOT EXISTS silver
    MANAGED LOCATION 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/silver';
CREATE SCHEMA IF NOT EXISTS gold
    MANAGED LOCATION 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/gold';

# %%
# %sql SHOW SCHEMAS;

# %% [markdown]
# 5 Create Volume

# %%
# %sql
USE CATALOG gizmobox;
USE SCHEMA landing;

CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data
    LOCATION 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/landing/operational_data/'
