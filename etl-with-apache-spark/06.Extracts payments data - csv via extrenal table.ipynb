# %% [markdown]
# 1.List the files from payment folder

# %%
# %fs ls 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/landing/external_data/payments'

# %% [markdown]
# 2. Create external table

# %%
# %sql
CREATE TABLE IF NOT EXISTS gizmobox.bronze.payments
( payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP,payment_status INTEGER, payment_method STRING)
USING CSV
OPTIONS (
    header = "true",
    delimeter = ","
)
LOCATION 'abfss://gizmobox@deacoursestacc.dfs.core.windows.net/landing/external_data/payments';

# %%
# %sql
SELECT * FROM gizmobox.bronze.payments;

# %%
# %sql DESCRIBE EXTENDED gizmobox.bronze.payments;

# %% [markdown]
# 3. Demo the effect of adding/updating/deleting files

# %%
# %sql
REFRESH TABLE gizmobox.bronze.payments;
    
SELECT * FROM gizmobox.bronze.payments;

# %% [markdown]
# Demo the effect of Dropping the Table

# %%
# %sql
DROP TABLE IF EXISTS gizmobox.bronze.payments;
