# %%
# %fs ls 'abfss://demo@deacoursestacc.dfs.core.windows.net/'

# %%
# %sql
CREATE EXTERNAL LOCATION  dea_course_ext_stac_demo
    URL 'abfss://demo@deacoursestacc.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL dea_course_ext_sc)

# %%
VALIDATE STORAGE CREDENTIAL dea_course_ext_sc
FOR READ FILES ON 'abfss://demo@deacourseextstac.dfs.core.windows.net/';
